# %%
import pandas as pd

# %%
orig = pd.read_csv('tikhonov_train.txt', sep='\t', header=0, names=['word', 'morphemes'])

# %%
orig
# Out:
#                     word                                      morphemes
# 0               грузовик                      груз:ROOT/ов:SUFF/ик:SUFF
# 1      краниометрический  крани:ROOT/о:LINK/метр:ROOT/ическ:SUFF/ий:END
# 2                зернить                       зерн:ROOT/и:SUFF/ть:SUFF
# 3            индуистский              инду:ROOT/ист:SUFF/ск:SUFF/ий:END
# 4                 набело                         на:PREF/бел:ROOT/о:END
# ...                  ...                                            ...
# 76691         кампешевый                     кампеш:ROOT/ев:SUFF/ый:END
# 76692          последний                            последн:ROOT/ий:END
# 76693           шататься             шат:ROOT/а:SUFF/ть:SUFF/ся:POSTFIX
# 76694       шахиншахский       шах:ROOT/ин:ROOT/шах:ROOT/ск:SUFF/ий:END
# 76695            роспуск                             рос:ROOT/пуск:ROOT
#
# [76696 rows x 2 columns]

# %%
def count_overlapping_substrings(haystack, needle):
    count = 0
    i = -1
    while True:
        i = haystack.find(needle, i+1)
        if i == -1:
            return count
        count += 1

# %%
def prepare_data(row):
    return count_overlapping_substrings(row['morphemes'], 'ROOT')

# %%
orig['result'] = orig.apply(prepare_data, axis=1)

# %%
orig[orig['result']>1].describe()
# Out:
#              result
# count  15053.000000
# mean       2.100512
# std        0.327348
# min        2.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        6.000000

# %%
orig[orig['result']>1]['word']
# Out:
# 1        краниометрический
# 6              полутоновый
# 9              психологист
# 16              криводушие
# 19            красногрудый
#                ...
# 76683     лжесвидетельница
# 76686               пухоед
# 76688            двугорбый
# 76694         шахиншахский
# 76695              роспуск
# Name: word, Length: 15053, dtype: object

# %%
test = pd.read_csv('ds_common_words_utf_8.csv')

# %%
test
# Out:
#                word  root
# 0            белить   бел
# 1        белобрысый   бел
# 2         белозубый   бел
# 3             белок   бел
# 4         белолицый   бел
# ...             ...   ...
# 1030       крашеный  крас
# 1031          окрас  крас
# 1032     подкрасить  крас
# 1033      раскраска  крас
# 1034  раскрашивание  крас
#
# [1035 rows x 2 columns]

# %%
def prepaire_root(row):
    root_split = row['root'].split('_')[0].split('(')
    base_root = root_split[0]
    if len(root_split) > 1:
        end_root = root_split[1][:-1]
        other_root = f'{base_root[:-len(end_root)]}{end_root}'
        if other_root in row['word']:
            return other_root
    return base_root

# %%
test['root'] = test.apply(prepaire_root, axis=1)

# %%
test.to_csv('prepaired_ds_common.csv', index=False)

# %%
merged = orig.merge(test,on=['word'])

# %%
def parse_morphemes(row):
    morphemes = row['morphemes'].split('/')
    roots = []
    for morph in morphemes:
        part, type_morph = morph.split(':')
        if type_morph == 'ROOT':
            if part.endswith('ь'):
                part = part[:-1]
            roots.append(part)
            
    return " ".join(roots)

# %%
merged[merged['result'] > 1]
# Out:
#                  word                                          morphemes  \
# 1        красногрудый                 красн:ROOT/о:LINK/груд:ROOT/ый:END
# 2     снегозадержание  снег:ROOT/о:LINK/за:PREF/держ:ROOT/ани:SUFF/е:END
# 6       хлебопродукты                хлеб:ROOT/о:LINK/продукт:ROOT/ы:END
# 12          раболепие              раб:ROOT/о:LINK/леп:ROOT/и:SUFF/е:END
# 31         белорыбица             бел:ROOT/о:LINK/рыб:ROOT/иц:SUFF/а:END
# ..                ...                                                ...
# 662          горемыка                     гор:ROOT/е:LINK/мык:ROOT/а:END
# 671           медонос                           мед:ROOT/о:LINK/нос:ROOT
# 683       белохвостый                  бел:ROOT/о:LINK/хвост:ROOT/ый:END
# 688       домохозяйка            дом:ROOT/о:LINK/хозяй:ROOT/к:SUFF/а:END
# 695  судопроизводство       суд:ROOT/о:LINK/производ:ROOT/ств:SUFF/о:END
#
#      result  root
# 1         2  крас
# 2         2  снег
# 6         2  хлеб
# 12        2   раб
# 31        2   бел
# ..      ...   ...
# 662       2   гор
# 671       2   мед
# 683       2   бел
# 688       2   дом
# 695       2   суд
#
# [166 rows x 4 columns]

# %%
merged['root']=merged.apply(parse_morphemes, axis=1)

# %%
for ind, r in merged.iterrows():
    if r['root'] not in r['roots']:
        print(ind, r['word'], r['roots'],r['root'])
# Out:
# 1 красногрудый ['красн', 'груд'] красн груд
# 2 снегозадержание ['снег', 'держ'] снег держ
# 6 хлебопродукты ['хлеб', 'продукт'] хлеб продукт
# 12 раболепие ['раб', 'леп'] раб леп
# 31 белорыбица ['бел', 'рыб'] бел рыб
# 34 водопад ['вод', 'пад'] вод пад
# 41 зверовод ['звер', 'вод'] звер вод
# 46 садовод ['сад', 'вод'] сад вод
# 48 спортзал ['спорт', 'зал'] спорт зал
# 54 листоед ['лист', 'ед'] лист ед
# 55 овощемоечный ['овощ', 'мо'] овощ мо
# 57 домосед ['дом', 'сед'] дом сед
# 58 словесник ['слов', 'ес'] слов ес
# 59 домостроение ['дом', 'стро'] дом стро
# 61 судовладелец ['суд', 'влад'] суд влад
# 64 травополье ['трав', 'пол'] трав пол
# 70 куровод ['кур', 'вод'] кур вод
# 71 жаропрочный ['жар', 'прочн'] жар прочн
# 74 лесостепь ['лес', 'степ'] лес степ
# 79 игротека ['игр', 'тек'] игр тек
# 89 ракета-носитель ['ракет', 'нос'] ракет нос
# 92 хлебозавод ['хлеб', 'завод'] хлеб завод
# 94 камнеломка ['камн', 'лом'] камн лом
# 96 утконос ['утк', 'нос'] утк нос
# 100 землекоп ['земл', 'коп'] земл коп
# 101 спортплощадка ['спорт', 'площадк'] спорт площадк
# 102 козерог ['коз', 'рог'] коз рог
# 104 конеферма ['кон', 'ферм'] кон ферм
# 105 зерноочистка ['зерн', 'чист'] зерн чист
# 107 словоизменение ['слов', 'мен'] слов мен
# 108 ледоруб ['лед', 'руб'] лед руб
# 111 словесный ['слов', 'ес'] слов ес
# 114 длинноносый ['длин', 'нос'] длин нос
# 117 краскопульт ['крас', 'пульт'] крас пульт
# 118 водоворот ['вод', 'ворот'] вод ворот
# 124 коневодство ['кон', 'вод'] кон вод
# 129 водовоз ['вод', 'воз'] вод воз
# 133 боеприпасы ['бо', 'пас'] бо пас
# 137 кружевоплетение ['кружев', 'плет'] кружев плет
# 138 конюх ['кон', 'юх'] кон юх
# 139 садоводство ['сад', 'вод'] сад вод
# 158 звездообразный ['звезд', 'образ'] звезд образ
# 159 конюшня ['кон', 'юш'] кон юш
# 160 судоходный ['суд', 'ход'] суд ход
# 161 белолобый ['бел', 'лоб'] бел лоб
# 162 овощеводство ['овощ', 'вод'] овощ вод
# 163 лесоруб ['лес', 'руб'] лес руб
# 167 солнцестояние ['солнц', 'сто'] солнц сто
# 168 солнцестояние ['солнц', 'сто'] солнц сто
# 169 пустоцвет ['пуст', 'цвет'] пуст цвет
# 177 победоносный ['побед', 'нос'] побед нос
# 179 буквоед ['букв', 'ед'] букв ед
# 185 добросовестный ['добр', 'совест'] добр совест
# 187 домочадец ['дом', 'чад'] дом чад
# 190 лесосека ['лес', 'сек'] лес сек
# 191 первоцвет ['перв', 'цвет'] перв цвет
# 192 медосбор ['мед', 'бор'] мед бор
# 194 земледелец ['земл', 'дел'] земл дел
# 197 словосочетание ['слов', 'сочет'] слов сочет
# 198 веснушчатый ['весн', 'ушч'] весн ушч
# 203 словотворчество ['слов', 'твор'] слов твор
# 209 овощесушилка ['овощ', 'суш'] овощ суш
# 210 листовидный ['лист', 'вид'] лист вид
# 216 словоохотливый ['слов', 'хот'] слов хот
# 224 зоосад ['зоо', 'сад'] зоо сад
# 227 домработница ['дом', 'работ'] дом работ
# 233 добровольный ['добр', 'вол'] добр вол
# 234 водолаз ['вод', 'лаз'] вод лаз
# 235 судостроение ['суд', 'стро'] суд стро
# 236 теплоход ['тепл', 'ход'] тепл ход
# 241 морозостойкий ['мороз', 'стой'] мороз стой
# 243 боевитость ['бо', 'евит'] бо евит
# 246 словообразование ['слов', 'образова', 'ние'] слов образова ние
# 249 коневод ['кон', 'вод'] кон вод
# 250 хлебопашец ['хлеб', 'паш'] хлеб паш
# 251 игрушечный ['игр', 'ушеч'] игр ушеч
# 256 горемычный ['гор', 'мыч'] гор мыч
# 263 белоручка ['бел', 'руч'] бел руч
# 267 домоводство ['дом', 'вод'] дом вод
# 273 вездеход ['везде', 'ход'] везде ход
# 279 зернохранилище ['зерн', 'хран'] зерн хран
# 283 кольцевидный ['кольц', 'вид'] кольц вид
# 287 хлебобулочный ['хлеб', 'булоч'] хлеб булоч
# 288 кольцеобразный ['кольц', 'образ'] кольц образ
# 289 солнцелюбивый ['солнц', 'люб'] солнц люб
# 291 овощехранилище ['овощ', 'хран'] овощ хран
# 298 спортинвентарь ['спорт', 'инвентар'] спорт инвентар
# 310 лосеферма ['лос', 'ферм'] лос ферм
# 312 дворняжка ['двор', 'яж'] двор яж
# 313 ракетоносец ['ракет', 'нос'] ракет нос
# 320 звероферма ['звер', 'ферм'] звер ферм
# 321 хлебопекарня ['хлеб', 'пек'] хлеб пек
# 329 лесопилка ['лес', 'пил'] лес пил
# 330 овощевод ['овощ', 'вод'] овощ вод
# 335 спортобщество ['спорт', 'общ'] спорт общ
# 353 водопой ['вод', 'пой'] вод пой
# 356 горесть ['гор', 'ест'] гор ест
# 364 картограф ['карт', 'граф'] карт граф
# 365 словоупотребление ['слов', 'потребл'] слов потребл
# 368 конокрад ['кон', 'крад'] кон крад
# 376 хлеборезка ['хлеб', 'рез'] хлеб рез
# 377 стройплощадка ['строй', 'площадк'] строй площадк
# 378 травоядный ['трав', 'яд'] трав яд
# 379 боеспособный ['бо', 'способн'] бо способн
# 380 звонкоголосый ['звон', 'голос'] звон голос
# 384 рабыня ['раб', 'ын'] раб ын
# 387 носорог ['нос', 'рог'] нос рог
# 391 зимостойкий ['зим', 'стой'] зим стой
# 399 овощерезка ['овощ', 'рез'] овощ рез
# 403 овощеводческий ['овощ', 'вод'] овощ вод
# 412 белоснежный ['бел', 'снеж'] бел снеж
# 417 домовладение ['дом', 'влад'] дом влад
# 438 коновязь ['кон', 'вяз'] кон вяз
# 439 головоломка ['голов', 'лом'] голов лом
# 440 зубробизон ['зубр', 'бизон'] зубр бизон
# 443 домовладелец ['дом', 'влад'] дом влад
# 448 землетрясение ['земл', 'тряс'] земл тряс
# 455 головомойка ['голов', 'мой'] голов мой
# 460 листообразный ['лист', 'образ'] лист образ
# 463 камнерез ['камн', 'рез'] камн рез
# 466 словесность ['слов', 'ес'] слов ес
# 478 травосеяние ['трав', 'се'] трав се
# 481 кожзаменитель ['кож', 'мен'] кож мен
# 483 солеварня ['сол', 'вар'] сол вар
# 496 красивенький ['крас', 'ив'] крас ив
# 499 водопровод ['вод', 'вод'] вод вод
# 500 ледорез ['лед', 'рез'] лед рез
# 503 снеготаяние ['снег', 'та'] снег та
# 505 кожеед ['кож', 'ед'] кож ед
# 511 картотека ['карт', 'тек'] карт тек
# 512 белошвейка ['бел', 'шв'] бел шв
# 524 холоднокровный ['холод', 'кров'] холод кров
# 529 луноход ['лун', 'ход'] лун ход
# 530 добродушный ['добр', 'душ'] добр душ
# 541 коновал ['кон', 'вал'] кон вал
# 542 снегурочка ['снег', 'уроч'] снег уроч
# 544 злословие ['зл', 'слов'] зл слов
# 548 стройбат ['строй', 'бат'] строй бат
# 552 гусыня ['гус', 'ын'] гус ын
# 555 спорткомплекс ['спорт', 'комплекс'] спорт комплекс
# 556 белозубый ['бел', 'зуб'] бел зуб
# 560 головотяп ['голов', 'тяп'] голов тяп
# 563 солнцеобразный ['солнц', 'образ'] солнц образ
# 576 камнепад ['камн', 'пад'] камн пад
# 583 веснушечка ['весн', 'ушеч'] весн ушеч
# 593 конезавод ['кон', 'завод'] кон завод
# 599 белолицый ['бел', 'лиц'] бел лиц
# 600 лесозащитный ['лес', 'защит'] лес защит
# 608 зверолов ['звер', 'лов'] звер лов
# 611 родители ['род', 'тел'] род тел
# 617 хлебороб ['хлеб', 'роб'] хлеб роб
# 618 спорттовары ['спорт', 'товар'] спорт товар
# 630 картография ['карт', 'граф'] карт граф
# 631 листопад ['лист', 'пад'] лист пад
# 632 солнцеворот ['солнц', 'ворот'] солнц ворот
# 634 хлебоуборочный ['хлеб', 'бор'] хлеб бор
# 635 цветовод ['цвет', 'вод'] цвет вод
# 643 камнеобработка ['камн', 'работ'] камн работ
# 645 землевладелец ['земл', 'влад'] земл влад
# 648 землемер ['земл', 'мер'] земл мер
# 660 звездоплавание ['звезд', 'пла'] звезд пла
# 662 горемыка ['гор', 'мык'] гор мык
# 671 медонос ['мед', 'нос'] мед нос
# 683 белохвостый ['бел', 'хвост'] бел хвост
# 688 домохозяйка ['дом', 'хозяй'] дом хозяй
# 695 судопроизводство ['суд', 'производ'] суд производ

# %%
test[test['word'].isin(orig['word'])]
# Out:
#                word  root
# 0            белить   бел
# 2         белозубый   бел
# 4         белолицый   бел
# 5         белолобый   бел
# 6         белоручка   бел
# ...             ...   ...
# 1030       крашеный  крас
# 1031          окрас  крас
# 1032     подкрасить  крас
# 1033      раскраска  крас
# 1034  раскрашивание  крас
#
# [697 rows x 2 columns]

# %%
result = merged

# %%
del result['morphemes']
del result['roots']
del result['result']
result
# Out:
#                  word          root
# 0            грузовик          груз
# 1        красногрудый    красн груд
# 2     снегозадержание     снег держ
# 3           воробышек         вороб
# 4             игровой           игр
# ..                ...           ...
# 692            конина           кон
# 693            курник           кур
# 694          березина         берез
# 695  судопроизводство  суд производ
# 696        расцветать          цвет
#
# [697 rows x 2 columns]

# %%
result
# Out:
#                  word          root
# 0            грузовик          груз
# 1        красногрудый    красн груд
# 2     снегозадержание     снег держ
# 3           воробышек         вороб
# 4             игровой           игр
# ..                ...           ...
# 692            конина           кон
# 693            курник           кур
# 694          березина         берез
# 695  судопроизводство  суд производ
# 696        расцветать          цвет
#
# [697 rows x 2 columns]

# %%
test[test['word'].isin(result['word'])]
# Out:
#                word  root
# 0            белить   бел
# 2         белозубый   бел
# 4         белолицый   бел
# 5         белолобый   бел
# 6         белоручка   бел
# ...             ...   ...
# 1030       крашеный  крас
# 1031          окрас  крас
# 1032     подкрасить  крас
# 1033      раскраска  крас
# 1034  раскрашивание  крас
#
# [697 rows x 2 columns]

# %%
for ind, r in result.iterrows():
    test.loc[test['word']==r['word'], 'root'] = r['root']

# %%
test.to_csv('ds_common_words_utf_8_for_test.csv', index=None)

# %%
test = test.sort_values(by=['word'])

# %%
test
# Out:
#            word      root
# 64       азбука     азбук
# 65     азбучный     азбуч
# 244   бездомный       дом
# 855  бездорожье     дорож
# 636     безухий        ух
# ..          ...       ...
# 586    цветовод  цвет вод
# 587    цветочек      цвет
# 588   цветочный      цвет
# 589    цветущий      цвет
# 590       цветы      цвет
#
# [1035 rows x 2 columns]
